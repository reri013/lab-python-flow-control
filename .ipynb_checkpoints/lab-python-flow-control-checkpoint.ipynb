# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
# FIRST LAB

# 1 Define a list called products that contains the following items: "t-shirt", "mug", "hat", "book", "keychain".
products = ["t-shirt", "mug", "hat", "book", "keychain"]


#2 Create an empty dictionary called inventory.
inventory = {}


    
#3 Ask the user to input the quantity of each product available in the inventory. Use the product names from the products list as keys in the inventory dictionary and assign the respective quantities as values.

for element in products: 
    quantity  = int (input (f"add number of {element} " ))
    inventory [element] = quantity
print (inventory)


#4 Create an empty set called customer_orders.

customer_orders = set()

#5 Ask the user to input the name of three products that a customer wants to order (from those in the products list, meaning three products out of "t-shirt", "mug", "hat", "book" or "keychain". Add each product name to the customer_orders set.

product1 = input ("enter the name of the first product: ")
customer_orders.add(product1)

product2 = input ("enter the name of the second product: ")
customer_orders.add(product2)

product3 = input ("enter the name of the third product: ")
customer_orders.add(product3)

#6 Print the products in the customer_orders set.

print (customer_orders)

#7 Calculate the following order statistics: 
#Total Products Ordered

total_ordered= len(customer_orders)
print (total_ordered)

#Total Products Ordered
percentage_product = (total_ordered / len(products)) * 100 
                      
order_status = (total_ordered, percentage_product )


#8 Print the order statistics using the following format:
print ("Order Statistics: ")
print ("Total Products ordered: ", total_ordered)
print ("Percentage of Products Ordered: " , percentage_product)

#9 Update the inventory by subtracting 1 from the quantity of each product. Modify the inventory dictionary accordingly.
inventory ["t'shirt"] -= 1
inventory ["mug"] -= 1
inventory ["hat"] -= 1
inventory ["book"] -= 1
inventory ["keychain"] -= 1
#10 Print the updated inventory, displaying the quantity of each product on separate lines.
print("uptdated inventory")
print(inventory)

# %%
# Seconde Lab 

#1 Look at your code from the lab data structures, and improve repeated code with loops.

products = ["t-shirt", "mug", "hat", "book", "keychain"]

inventory = {}



for element in products: 
    quantity  = int (input (f"add number of {element} " ))
    inventory [element] = quantity
print (inventory)





customer_orders = set()



 
for a in range (3) :
    product = input (f"enter the name of the {a+1} product: ")
    customer_orders.add(product)
    
print (customer_orders)




print (customer_orders)




total_ordered= len(customer_orders)
print (total_ordered)




percentage_product = (total_ordered / len(products)) * 100 
                      
order_status = (total_ordered, percentage_product )




print ("Order Statistics: ")
print ("Total Products ordered: ", total_ordered)
print ("Percentage of Products Ordered: " , percentage_product)


for items  in inventory :
    inventory [ product] -=1



print("uptdated inventory")
for product, quantity in inventory.items():
    print( "quantity of " ,product, "is :",quantity)
# Out:
# add number of t-shirt 2
# add number of mug 33
# add number of hat 2
# add number of book 12
# add number of keychain 3
# {'t-shirt': 2, 'mug': 33, 'hat': 2, 'book': 12, 'keychain': 3}
# enter the name of the 1 product: t'shirt
# enter the name of the 2 product: mug
# enter the name of the 3 product: hat
# {'hat', 'mug', "t'shirt"}
# {'hat', 'mug', "t'shirt"}
# 3
# Order Statistics:
# Total Products ordered:  3
# Percentage of Products Ordered:  60.0
# uptdated inventory
# quantity of  t-shirt is : 2
# quantity of  mug is : 33
# quantity of  hat is : -3
# quantity of  book is : 12
# quantity of  keychain is : 3

# %%
#2  Instead of asking the user to input the name of three products that a customer wants to order, do the following:

#a. Prompt the user to enter the name of a product that a customer wants to order.

#b. Add the product name to the "customer_orders" set.

#c. Ask the user if they want to add another product (yes/no).

#d. Continue the loop until the user does not want to add another product.

while  input("do you want to add another product: ").lower() == "yes" : 
    product = input("enter the name of the product: ")
    customer_oders.add(product)

# %%
#3 Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for the products that were ordered (those in "customer_orders").
